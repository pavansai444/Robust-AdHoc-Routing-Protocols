# %%
import numpy as np
import pandas as pd
from scipy.spatial import distance
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(list([10,20,30,40,60,80,100]), list([82.573,39.2734,26.0325,19.26744,15.435,11.22,8.021]),'bo')
plt.plot(list([10,20,30,40,60,80,100]), list([82.573,39.2734,26.0325,19.26744,15.435,11.22,8.021]))
plt.xlabel("Number of Nodes")
plt.ylabel("throughput(kbps)")
plt.grid(True)
plt.show()

# %%
x = list([10,20,30,40,60,80,100])
y = [99.27,98.34,97.48,97.97,98.46,97.94,97.92]
plt.plot(x,y,'bo')
plt.plot(x, y)
plt.xlabel("Number of Nodes")
plt.ylabel("Packet Delivery Ratio(%)")
plt.grid(True)
plt.show()

# %%
plt.plot([10,20,30,40,60,80,100], list([370.37,327.44,666.64,630.20,180.61,243.96,240.15]),'bo')
plt.plot([10,20,30,40,60,80,100], list([370.37,327.44,666.64,630.20,180.61,243.96,240.15]))
plt.xlabel("Number of Nodes")
plt.ylabel("Average End to End Delay(ms)")
plt.grid(True)
plt.show()

# %%
plt.plot([10,20,30,40,60,80,100], list([4.03,4.72,7.34,10.10,3.74,5.10,5.76]),'bo')
plt.plot([10,20,30,40,60,80,100], list([4.03,4.72,7.34,10.10,3.74,5.10,5.76]))
plt.xlabel("Number of Nodes")
plt.ylabel("Normalized Routing Load")
plt.grid(True)
plt.show()

# %%
x = list([10,20,30,40,60,80,100])
y = [713.901,1348.9,1956.63,2592.66,4335.18,5705.23,6817.95]
plt.plot(x,y,'bo')
plt.plot(x, y)
plt.xlabel("Number of Nodes")
plt.ylabel("Total energy consumed")
plt.grid(True)
plt.show()
