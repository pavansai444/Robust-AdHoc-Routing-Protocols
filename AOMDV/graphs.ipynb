# %% [markdown]
# ### Aodv single

# %%
plt.plot(list([11,21,31,41]), list([ 259.182,52.8723,254.403, 106.529]),'bo')
plt.plot(list([11,21,31,41]), list([ 259.182,52.8723,254.403, 106.529]))
plt.xlabel("Number of Nodes")
plt.ylabel("throughput(kbps)")
plt.grid(True)
plt.show()

# %%
plt.plot(list([11,21,31,41]), list([143.40,86.60,124.68, 308.60]),'bo')
plt.plot(list([11,21,31,41]), list([143.40,86.60,124.68, 308.60]))
plt.xlabel("Number of Nodes")
plt.ylabel("delay(ms)")
plt.grid(True)
plt.show()

# %%
plt.plot(list([11,21,31,41]), list([98.9536, 224.86, 274.237, 443.477]),'bo')
plt.plot(list([11,21,31,41]), list([98.9536, 224.86, 274.237, 443.477]))
plt.xlabel("Number of Nodes")
plt.ylabel("total energy consumed()")
plt.grid(True)
plt.show()

# %%
plt.plot(list([11,21,31,41]), list([0.75,11.37,  5.29, 158.26]),'bo')
plt.plot(list([11,21,31,41]), list([0.75,11.37,  5.29, 158.26]))
plt.xlabel("Number of Nodes")
plt.ylabel("Normalized roting load")
plt.grid(True)
plt.show()

# %%
sent_packs=[2174,466,2120,140]
recv_packs=[2172,442,2099,117]
drop_perc=[]
for i in range(len(sent_packs)):
    drop_perc.append(((recv_packs[i])/sent_packs[i])*100)
plt.plot(list([11,21,31,41]), drop_perc,'bo')
plt.plot(list([11,21,31,41]), drop_perc)
plt.xlabel("Number of Nodes")
plt.ylabel("delivery percentage")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Aomdv multiple

# %%
plt.plot(list([10,20,30,40,60,80,100]), list([ 152.416/2,183.62/5,202.608/7,222.33/9,748.495/38,612.735/48,656.298/76]),'bo')
plt.plot(list([10,20,30,40,60,80,100]), list([ 152.416/2,183.62/5,202.608/7,222.33/9,748.495/38,612.735/48,656.298/76]))
plt.xlabel("Number of Nodes")
plt.ylabel("throughput(kbps)")
plt.grid(True)
plt.show()

# %%
plt.plot(list([10,20,30,40,60,80,100]), list([443.34,589.57,812.22,828.37, 208.98,274.15, 307.59]),'bo')
plt.plot(list([10,20,30,40,60,80,100]), list([443.34,589.57,812.22,828.37, 208.98,274.15, 307.59]))
plt.xlabel("Number of Nodes")
plt.ylabel("delay(ms)")
plt.grid(True)
plt.show()

# %%
sent_packs=[11234.00,13471,14957,16431,55150,45248,48686]
recv_packs=[11106,13204,14613,16036,54240,44427,47325]
drop_perc=[]
for i in range(len(sent_packs)):
    drop_perc.append(((recv_packs[i])/sent_packs[i])*100)
plt.plot(list([10,20,30,40,60,80,100]), drop_perc,'bo')
plt.plot(list([10,20,30,40,60,80,100]), drop_perc)
plt.xlabel("Number of Nodes")
plt.ylabel("delivery percentage")
plt.grid(True)
plt.show()

# %%
plt.plot(list([10,20,30,40,60,80,100]), list([708.877,1322.13,1940.43,2563.03, 4292.92,5595.12,6766.19]),'bo')
plt.plot(list([10,20,30,40,60,80,100]), list([708.877,1322.13,1940.43,2563.03, 4292.92,5595.12,6766.19]))
plt.xlabel("Number of Nodes")
plt.ylabel("total energy(joules)")
plt.grid(True)
plt.show()

# %%
plt.plot(list([10,20,30,40,60,80,100]), list([0.69,2.56,4.99,7.64,2.33,5.62,10.51]),'bo')
plt.plot(list([10,20,30,40,60,80,100]), list([0.69,2.56,4.99,7.64,2.33,5.62,10.51]))
plt.xlabel("Number of Nodes")
plt.ylabel("Normalized roting load")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Dymo multiple

# %%
plt.plot(list([10,20,30,40,60,80,100]), list([ 157.599/2, 202.43/5,223.741/7,226.442/9,624.945/38,612.735/48, 857.722 /76]),'bo')
plt.plot(list([10,20,30,40,60,80,100]), list([ 157.599/2, 202.43/5,223.741/7,226.442/9,624.945/38,612.735/48, 857.722 /76]))
plt.xlabel("Number of Nodes")
plt.ylabel("throughput(kbps)")
plt.grid(True)
plt.show()

# %%
plt.plot(list([10,20,30,40,60,80,100]), list([ 351.89, 479.55,657.10,732.80,224.31,223.52,239.59]),'bo')
plt.plot(list([10,20,30,40,60,80,100]), list([ 351.89, 479.55,657.10,732.80,224.31,223.52,239.59]))
plt.xlabel("Number of Nodes")
plt.ylabel("delay(ms)")
plt.grid(True)
plt.show()

# %%
sent_packs=[11558,14924, 16465,16774,46039,52068,19268]
recv_packs=[11444,14646,16152,16336,45159, 51147,18634]
drop_perc=[]
for i in range(len(sent_packs)):
    drop_perc.append(((recv_packs[i])/sent_packs[i])*100)
plt.plot(list([10,20,30,40,60,80,100]), drop_perc,'bo')
plt.plot(list([10,20,30,40,60,80,100]), drop_perc)
plt.xlabel("Number of Nodes")
plt.ylabel("delivery percentage")
plt.grid(True)
plt.show()

# %%
plt.plot(list([10,20,30,40,60,80,100]), list([702.849,1322.67,1937.33,2558.91,4218.48, 5538.91,2061.61]),'bo')
plt.plot(list([10,20,30,40,60,80,100]), list([702.849,1322.67,1937.33,2558.91,4218.48, 5538.91,2061.61]))
plt.xlabel("Number of Nodes")
plt.ylabel("total energy(joules)")
plt.grid(True)
plt.show()

# %%
plt.plot(list([10,20,30,40,60,80,100]), list([0.07,0.73,1.59,4.16,0.98,2.70,5.97]),'bo')
plt.plot(list([10,20,30,40,60,80,100]), list([0.07,0.73,1.59,4.16,0.98,2.70,5.97]))
plt.xlabel("Number of Nodes")
plt.ylabel("Normalized roting load")
plt.grid(True)
plt.show()
